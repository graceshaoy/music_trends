# %% [markdown]
# # I. What drives the homogenization/heterogenization of music?

# %% [markdown]
# In the previous notebook (check_horkheimer), I found that while Horkheimer was right in that different and successful songs had many imitators, there was not strong evidence that genres became more specific as time went on.
#
# Instead of Horkheimer's theory of homogenization, I propose that there is a constant cycle of homogenization and heterogenization of music as a result of the constant tension between the dominant culture and subcultures. My general framework for understanding this tension comes from Hebdige's *Subculture: The Meaning of Style*. The pattern of how trends spread follows the pattern of complex contagions, as described by Guilbeault et. al. in *Complex Contagions: A Decade in Review*. What specific trends catch on depends on the circuit of production, similar to the design of the Sony Walkman as outlined by duGay et. al. in Chapter 2 of *Doing Cultural Studies*.
#
# In *Subcultures: The Meaning of Style*, Hebdige criticizes how structural Marxism explains the reproduction of structures, but has no explanation for change. Hebdige defines style in subculture as gestures that challenge the cohesion of dominant culture. He uses the punk aesthetic as an example of a subculture that represented the white working class British youth as a response to the social unease in the post-war period. Out of objects such as safety pins, which were used to hold clothes together, it created "tokens of a self-imposed exile" (Hebdige 2). However, the image of social cohesion is maintained through the appropriation and redefinition of cultures of resistance. Thus, punk style was commodified and labelled as both trivial and a spectacle: "Youth cultural styles may begin by issuing symbolic challenges, but they must inevitably end by establishing new sets of conventions" (Hebidge 96).
#
# Hebdige's explanation of subcultures can be generalized from subcultures that directly challenge the cohesion of dominant culture to cultures that are "other". Here, we consider Korean pop music as an example, since it became a trend recently, so data on its popularity is more accesible than the punk aesthetic. Similar to how safety pins were appropriated and commodified outside of the original subculture, the subculture of Korean culture has been commodified in the US.
#
# Thus, my theory agrees with Horkehimer that "anyone who resists can survive only by being incorporated" (Horkheimer 104) through the commodification of subcultures. However, since there is a constant tension between hegemony and subcultures, I disagree that the wheel spins in place. Rather, the wheel travels subcultures. Additionally, since the framework of dominant majority and subcultures can be used recursively, there are sub-subcultures within subcultures that keep subcultures from converging to a formulaic process. In the kpop example, a sub-subculture within this genre are Chinese-speaking groups that were not represented in the dominant culture, leading to kpop groups that also create chinese ...
#
# The popularity of subcultures exist within the circuit of production. With the punk subculture, the safety pins initially represented an identity of working-class youth that challenged the dominant culture, but was eventually commodified and turned into a costume that consumers could put on. With kpop, popular music within South Korea was pushed outside its home country though the government's efforts.
#
#
# maybe horkheimer right that it did freeze, but wrong that it all originates from top
# originates bottom up (punk, kpop), then once popular becomes commodified
#
# - explain hebdige punk example
# - explain subculture from oppressed / another / other
# - korean is other
# - why korean / punk become popular? bc complex contagion & korean government fund this soft power to target audience
# - (compare to horkheimer throughout)
# - once popular, becomes an industry -- kpop has manufactured -- walkman
#
# - because kpop was manufactured by kgov, we can show how subcultures become incorporated and follow complex contagions, --> there's always "other". however, kpop industry was manufac, so does not disprove horkheimer conspiratorial part.
#
# ### horkheimer quotes
# "The general designation 'culture' alreaady contains, virtually, the process of identifyin, cataloging, and classifying which imports culture into the realm of administration. Only what has been industrialized, rigorously subsumed, is fullly adequate to this concept of culture." 104
# "Not only do hit songs, stars, and soap operas conform to types recurring cyclically as rigid invariants, but the specific content of productions, the seemingly variable element, is itself derived from those types." 98
# "Anyone who resists can survive only by being incorporated" 104
# "Sharp distinctions...do not so much reflect real differences as assist in the classification, organization, and identification of consumers. Something is provided for everyone so that no one can escape; differences are hammered home and propagated" 97 -- agree that classification (those that like kpop are also more into kbeauty), but not that no one can escape, differences are not hammered bc differences will always exist
# "Through totality, the culture industry is putting an end to all that...it subdues their unruliness and subordinates them to the formula which supplants the work." 99
#
# ### hebdige quotes
# "Society cannot share a common communication system so long as it is split into warring classes" (Brecht, *A Short Organum for the Theatre* in Hebdige 15)
# "a credible image of social cohesion can only be maintained through the appropriation and redefinition of cultures of resistance" (Hebdige 85)
# "as soon as the original innovations which signify 'subcultre' are translated into commodities and made generally available, they become 'frozen'.Once removed from their private contexts by the small entrepreneurs and big fashion interests who produce them on a mass scale, they become codified, made comprehensible, rended at once public property and profitable merchandise. (hebdige 96)
# "Youth cultural styles may begin by issuing symbolic challenges, but they must inevitably end by estabilshing new sets of conventions; by creating new commodities, new industries or rejuvenating old ones" (96)

# %%
import importlib
import music
importlib.reload(music)

import access
# from access import *
importlib.reload(access)
# Out:
# <module 'access' from 'c:\\Users\\grace\\Desktop\\macs_404_patterns\\music_trends\\access.py'>

# %%
import youtube_dl
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import lyricsgenius
import requests
from rauth import OAuth2Service

import re
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 150
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # II. Get data

# %% [markdown]
# ### From spotify

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = access.spotify_client_id, client_secret = access.spotify_client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

r = requests.post('https://accounts.spotify.com/api/token',
data ={'grant_type': 'client_credentials'},auth=(access.client_id, access.client_secret))
bearer = dict(r.json())['access_token']

# %%
categories_df = pd.DataFrame(sp.categories(limit=50)['categories']['items'])
np.array(categories_df['name'])
# Out:
# array(['Top Lists', 'Hip-Hop', 'Pop', 'Country', 'Latin', 'Rock',
#        'Summer', 'Workout', 'R&B', 'Dance/Electronic', 'Netflix', 'Indie',
#        'Mood', 'Sleep', 'Christian & Gospel', 'Regional Mexican',
#        'Wellness', 'Chill', 'EQUAL', 'Gaming', 'Frequency', 'Pride',
#        'Kids & Family', 'Party', 'Decades', 'Fresh Finds', 'Jazz',
#        'Focus', 'Romance', 'Folk & Acoustic', 'K-Pop', 'Instrumental',
#        'Sports', 'Ambient', 'Alternative', 'In the car', 'theLINER',
#        'Classical', 'Soul', 'Spotify Singles', 'Cooking & Dining', 'Punk',
#        'Pop culture', 'Blues', 'Desi', 'Arab', 'RADAR', 'Student',
#        'Anime', 'Tastemakers'], dtype=object)

# %%
r = requests.get('https://api.spotify.com/v1/recommendations/available-genre-seeds', headers={'Authorization': 'Bearer ' + bearer})
all_genres = set(r.json()['genres'])
hottopic_genres = ['rock','garage','hip-hop','k-pop','metal','punk','emo','anime']
# k-pop not included bc can't differentiate btwn interest in south korea and in US (where it would have started as "alternative"/subculture)

# %%
genre_dict = {}
for genre in hottopic_genres:
    # genre_dict[genre] = pd.DataFrame()
    # for year in range(1960,2022):
    #     year_df = music.spotify_query(genre,year)
    #     print(genre, year)
    #     genre_dict[genre] = pd.concat([genre_dict[genre],year_df])
    # genre_dict[genre] = music.get_audio_features(genre_dict[genre])
    # genre_dict[genre].to_csv(f'subculture_music\{genre}.csv')
    genre_dict[genre] = pd.read_csv(f'pt2_files\subculture_music\{genre}.csv', index_col=0)

# %%
# subculture_df = pd.DataFrame()
# for genre in hottopic_genres:
#     genre_df = genre_dict[genre].copy()
#     genre_df['genre'] = genre
#     subculture_df = pd.concat([subculture_df,genre_df])
# subculture_df.to_csv('pt2_files\subculture_df.csv')
subculture_df = pd.read_csv('pt2_files\subculture_df.csv', index_col=0)
subculture_df.head()
# Out:
#                                         artist_name  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX    Neil Sedaka
# spotify:track:2OCoH12t6olzx9bT1PEC8F    Chuck Berry
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq  Eddie Cochran
# spotify:track:7B2pUwzvlbNG9D855r9ugf   The Ventures
# spotify:track:1BIGqqQxGV9c45heFmUxLL      Sam Cooke
#
#                                                         track_name  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX     Breaking Up Is Hard to Do
# spotify:track:2OCoH12t6olzx9bT1PEC8F  Let It Rock - Single Version
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq               C’Mon Everybody
# spotify:track:7B2pUwzvlbNG9D855r9ugf      Walk, Don't Run - Stereo
# spotify:track:1BIGqqQxGV9c45heFmUxLL          That's Where It's At
#
#                                       popularity                track_id  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX        56.0  2x6pbpjVGjiWCcH89IK8AX
# spotify:track:2OCoH12t6olzx9bT1PEC8F        56.0  2OCoH12t6olzx9bT1PEC8F
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq        58.0  7ItZM6DMZE2m1X7yIaRxjq
# spotify:track:7B2pUwzvlbNG9D855r9ugf        49.0  7B2pUwzvlbNG9D855r9ugf
# spotify:track:1BIGqqQxGV9c45heFmUxLL        50.0  1BIGqqQxGV9c45heFmUxLL
#
#                                      release_date  year  danceability  energy  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX   1960-12-30  1960         0.743   0.799
# spotify:track:2OCoH12t6olzx9bT1PEC8F   1960-01-01  1960         0.632   0.716
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq   1960-05-01  1960         0.627   0.700
# spotify:track:7B2pUwzvlbNG9D855r9ugf   1960-01-01  1960         0.488   0.648
# spotify:track:1BIGqqQxGV9c45heFmUxLL   1960-01-01  1960         0.516   0.450
#
#                                       key  loudness  ...  liveness  valence  \
# uri                                                  ...
# spotify:track:2x6pbpjVGjiWCcH89IK8AX    8    -5.466  ...    0.0635    0.965
# spotify:track:2OCoH12t6olzx9bT1PEC8F   10   -12.387  ...    0.1810    0.935
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq    3    -9.657  ...    0.1880    0.856
# spotify:track:7B2pUwzvlbNG9D855r9ugf    5   -13.252  ...    0.1300    0.949
# spotify:track:1BIGqqQxGV9c45heFmUxLL    0    -9.318  ...    0.1970    0.647
#
#                                         tempo            type  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX  116.112  audio_features
# spotify:track:2OCoH12t6olzx9bT1PEC8F  164.851  audio_features
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq  175.330  audio_features
# spotify:track:7B2pUwzvlbNG9D855r9ugf  156.350  audio_features
# spotify:track:1BIGqqQxGV9c45heFmUxLL  100.208  audio_features
#
#                                                           id  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX  2x6pbpjVGjiWCcH89IK8AX
# spotify:track:2OCoH12t6olzx9bT1PEC8F  2OCoH12t6olzx9bT1PEC8F
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq  7ItZM6DMZE2m1X7yIaRxjq
# spotify:track:7B2pUwzvlbNG9D855r9ugf  7B2pUwzvlbNG9D855r9ugf
# spotify:track:1BIGqqQxGV9c45heFmUxLL  1BIGqqQxGV9c45heFmUxLL
#
#                                                                              track_href  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX  https://api.spotify.com/v1/tracks/2x6pbpjVGjiW...
# spotify:track:2OCoH12t6olzx9bT1PEC8F  https://api.spotify.com/v1/tracks/2OCoH12t6olz...
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq  https://api.spotify.com/v1/tracks/7ItZM6DMZE2m...
# spotify:track:7B2pUwzvlbNG9D855r9ugf  https://api.spotify.com/v1/tracks/7B2pUwzvlbNG...
# spotify:track:1BIGqqQxGV9c45heFmUxLL  https://api.spotify.com/v1/tracks/1BIGqqQxGV9c...
#
#                                                                            analysis_url  \
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX  https://api.spotify.com/v1/audio-analysis/2x6p...
# spotify:track:2OCoH12t6olzx9bT1PEC8F  https://api.spotify.com/v1/audio-analysis/2OCo...
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq  https://api.spotify.com/v1/audio-analysis/7ItZ...
# spotify:track:7B2pUwzvlbNG9D855r9ugf  https://api.spotify.com/v1/audio-analysis/7B2p...
# spotify:track:1BIGqqQxGV9c45heFmUxLL  https://api.spotify.com/v1/audio-analysis/1BIG...
#
#                                      duration_ms time_signature genre
# uri
# spotify:track:2x6pbpjVGjiWCcH89IK8AX      139200              4  rock
# spotify:track:2OCoH12t6olzx9bT1PEC8F      102800              4  rock
# spotify:track:7ItZM6DMZE2m1X7yIaRxjq      118227              4  rock
# spotify:track:7B2pUwzvlbNG9D855r9ugf      122933              4  rock
# spotify:track:1BIGqqQxGV9c45heFmUxLL      155320              3  rock
#
# [5 rows x 24 columns]

# %% [markdown]
# ### From genius

# %%
genius = OAuth2Service(client_id=access.genius_client_id, client_secret=access.genius_client_secret, name='genius', authorize_url='https://api.genius.com/oauth/authorize', access_token_url='https://api.genius.com/oauth/token', base_url='https://api.genius.com/')
genius = lyricsgenius.Genius(access.genius_access_token)
genius.verbose = False
genius.remove_section_headers = True

# %%
# cardigan = genius.search_song('cardigan', 'taylor swift').lyrics
cardigan[cardigan.find('Lyrics')+7:].replace('\n',' ')
# Out:
# "Vintage tee, brand new phone High heels on cobblestones When you are young, they assume you know\u2005nothing Sequin\u2005smile, black lipstick Sensual\u2005politics When you are young, they assume\u2005you know nothing  But I knew you Dancin' in your Levi's Drunk under a streetlight, I I knew you Hand under my sweatshirt Baby, kiss it better, I And when I felt like I was an old cardigan Under someone's bed You put me on and said I was your favorite  A friend to all is a friend to none Chase two girls, lose the one When you are young, they assume you know nothing  But I knew you Playing hide-and-seek and Giving me your weekends, I I knew you Your heartbeat on the High Line Once in twenty lifetimes, I  And when I felt like I was an old cardigan Under someone's bed You put me on and said I was your favorite  To kiss in cars and downtown bars Was all we needed You drew stars around my scars But now I'm bleedin' See Taylor Swift LiveGet tickets as low as $325You might also like 'Cause I knew you Steppin' on the last train Marked me like a bloodstain, I I knew you Tried to change the ending Peter losing Wendy, I I knew you Leavin' like a father Running like water, I And when you are young, they assume you know nothing  But I knew you'd linger like a tattoo kiss I knew you'd haunt all of my what-ifs The smell of smoke would hang around this long 'Cause I knew everything when I was young I knew I'd curse you for the longest time Chasin' shadows in the grocery line I knew you'd miss me once the thrill expired And you'd be standin' in my front porch light And I knew you'd come back to me You'd come back to me And you'd come back to me And you'd come back And when I felt like I was an old cardigan Under someone's bed You put me on and said I was your favorite169Embed"

# %% [markdown]
# # III. Analysis

# %% [markdown]
# ## spotify data

# %% [markdown]
# #### by popularity

# %%
by_popularity = pd.DataFrame(subculture_df.groupby(['genre','year'])['popularity'].mean())

# %%
# find when each genre first had a popularity score above 20
first_above_20 = {}
for genre in hottopic_genres:
    first_above_20[genre] = by_popularity.loc[genre][by_popularity.loc[genre].rolling(5).mean()['popularity'] > 21].index[0]
order = pd.DataFrame({'genre':first_above_20.keys(), 'year':first_above_20.values()}).sort_values('year')
hottopic_genres = list(order['genre'])
order
# Out:
#      genre  year
# 0     rock  1966
# 4    metal  1987
# 2  hip-hop  1995
# 5     punk  1996
# 3    k-pop  2010
# 6      emo  2012
# 1   garage  2014
# 7    anime  2014

# %%
for genre in hottopic_genres:
    plt.plot(by_popularity.loc[genre].rolling(5).mean(), label=genre)
plt.plot([1960,2022],[20,20], linestyle='--', color='black',alpha=0.5)
# 20 is when a song is pushed to users that aren't already following the artist https://lodgecove.com/what-is-the-spotify-popularity-index/
plt.legend(bbox_to_anchor=(1.05, 1))
plt.xlabel('Year')
plt.ylabel('Spotify Popularity Score')
# Out:
# Text(0, 0.5, 'Spotify Popularity Score')

# %% [markdown]
# ### by releases per year

# %%
by_count = pd.DataFrame(subculture_df.groupby(['genre','year'])['id'].count())

# find when each genre first had a count of 1000
first_maxed = {}
for genre in hottopic_genres:
    first_maxed[genre] = by_count.loc[genre][by_count.loc[genre].rolling(5).mean()['id'] >= 999].index[0]

# subtract the first year each genre had a count of 1000 from the first column of by_count
by_count['first_maxed'] = by_count.index.get_level_values(1) - by_count.index.get_level_values(0).map(first_maxed)
# by_count = by_count.drop_duplicates()

# %%
tracks_by_year = {}
for genre in genre_dict.keys():
    tracks_by_year[genre] = genre_dict[genre].groupby('year').count()['id']
    tracks_by_year[genre].rolling(5).mean().plot(label=genre)
plt.legend()
plt.ylabel('releases')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
pd.DataFrame({'genre':first_maxed.keys(), 'year':first_maxed.values()}).sort_values('year')
# Out:
#      genre  year
# 0     rock  1964
# 5     punk  1981
# 4    metal  1987
# 3    k-pop  1989
# 2  hip-hop  1994
# 6      emo  2005
# 1   garage  2006
# 7    anime  2007

# %%
complex_contagion = music.full_simulate_net_diffusion()
complex_contagion['relative'] = complex_contagion['Execution'] - complex_contagion['Execution'][np.argmax(complex_contagion['Infected'])]
complex_contagion = complex_contagion.groupby('Execution')['Infected'].mean().reset_index()
complex_contagion['Infected'] = (complex_contagion['Infected']  / max(complex_contagion['Infected'])) * 1000

# %%
complex_contagion['relative'] = complex_contagion['Execution'] - complex_contagion['Execution'][np.argmax(complex_contagion['Infected'])]
complex_contagion['relative'] = complex_contagion['relative'] * 7
complex_contagion = complex_contagion[:np.argmax(complex_contagion['Infected'])+1]

# %%
plt.plot(complex_contagion['relative'], complex_contagion['Infected'], label='complex contagion', color='black',linestyle=':')
for genre in hottopic_genres:
    plt.plot(by_count.loc[genre]['first_maxed'], by_count.loc[genre]['id'].rolling(5).mean(), label=genre, alpha=0.3)
# sns.lineplot(x='Execution', y='Infected', data=complex_contagion, label='Simulated Results', color='black')
leg = plt.legend(bbox_to_anchor=(1.05, 1))
for l in leg.legendHandles:
    l.set_alpha(1)
leg
plt.xlabel('year relative to first year with 1000 songs')
plt.ylabel('releases')
# Out:
# Text(0, 0.5, 'releases')

# %%
vars_audio = ['speechiness','acousticness','instrumentalness','tempo','liveness','energy','danceability','loudness']
standarized = subculture_df.copy().dropna()
for var in vars_audio:
    standarized[var] = (standarized[var] - standarized[var].mean())/standarized[var].std()
by_genre = {}
for genre in hottopic_genres:
    by_genre[genre] = standarized[standarized['genre'] == genre]

# %%
music.plot_numerical_std(vars_audio, hottopic_genres, by_genre, legend=True)
